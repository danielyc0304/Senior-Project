# %%
TICKER = "2330.TW"
START_TIME = "2020-01-01"
INTERVAL = "1d"
FEATURES = ["Close"]
SEQ_LEN = 30

# %%
from datetime import datetime, timedelta
import yfinance as yf
import pandas as pd
import ta


start_time = datetime.strptime(START_TIME, "%Y-%m-%d")
start_time_prev = start_time - timedelta(days=SEQ_LEN * 2)
end_time_prev = start_time - timedelta(days=1)

df = yf.download(
    TICKER,
    start=START_TIME,
    end="2025-12-31",
    interval=INTERVAL,
)
df_prev = yf.download(
    TICKER,
    start=start_time_prev,
    end=end_time_prev,
    interval=INTERVAL,
)
if df is None or df.empty or df_prev is None or df_prev.empty:
    raise ValueError("Failed to download train data")

df_all = pd.concat([df_prev, df])
df_all.columns = df_all.columns.droplevel(1)
df_all = ta.add_all_ta_features(
    df_all, open="Open", high="High", low="Low", close="Close", volume="Volume"
)

print(df_all.columns)

df_prev, df = df_all[:START_TIME], df_all[START_TIME:]
data_prev, data = df_prev[FEATURES].to_numpy(), df[FEATURES].to_numpy()

print(data_prev.shape, data.shape)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'volume_adi', 'volume_obv',
#        'volume_cmf', 'volume_fi', 'volume_em', 'volume_sma_em', 'volume_vpt',
#        'volume_vwap', 'volume_mfi', 'volume_nvi', 'volatility_bbm',
#        'volatility_bbh', 'volatility_bbl', 'volatility_bbw', 'volatility_bbp',
#        'volatility_bbhi', 'volatility_bbli', 'volatility_kcc',
#        'volatility_kch', 'volatility_kcl', 'volatility_kcw', 'volatility_kcp',
#        'volatility_kchi', 'volatility_kcli', 'volatility_dcl',
#        'volatility_dch', 'volatility_dcm', 'volatility_dcw', 'volatility_dcp',
#        'volatility_atr', 'volatility_ui', 'trend_macd', 'trend_macd_signal',
#        'trend_macd_diff', 'trend_sma_fast', 'trend_sma_slow', 'trend_ema_fast',
#        'trend_ema_slow', 'trend_vortex_ind_pos', 'trend_vortex_ind_neg',
#        'trend_vortex_ind_diff', 'trend_trix', 'trend_mass_index', 'trend_dpo',
#        'trend_kst', 'trend_kst_sig', 'trend_kst_diff', 'trend_ichimoku_conv',
#        'trend_ichimoku_base', 'trend_ichimoku_a', 'trend_ichimoku_b',
#        'trend_stc', 'trend_adx', 'trend_adx_pos', 'trend_adx_neg', 'trend_cci',
#        'trend_visual_ichimoku_a', 'trend_visual_ichimoku_b', 'trend_aroon_up',
#        'trend_aroon_down', 'trend_aroon_ind', 'trend_psar_up',
#        'trend_psar_down', 'trend_psar_up_indicator',
#        'trend_psar_down_indicator', 'momentum_rsi', 'momentum_stoch_rsi',
#        'momentum_stoch_rsi_k', 'momentum_stoch_rsi_d', 'momentum_tsi',
#        'momentum_uo', 'momentum_stoch', 'momentum_stoch_signal', 'momentum_wr',
#        'momentum_ao', 'momentum_roc', 'momentum_ppo', 'momentum_ppo_signal',
#        'momentum_ppo_hist', 'momentum_pvo', 'momentum_pvo_signal',
#        'momentum_pvo_hist', 'momentum_kama', 'others_dr', 'others_dlr',
#        'others_cr'],
#       dtype='str', name='Price')
# (41, 1) (1456, 1)

# %%
split = int(len(data) * 0.8)
train, test = data[:split], data[split:]

print(train.shape, test.shape)
# Out:
# (1164, 1) (292, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np


scaler = MinMaxScaler()
scaler.fit(np.concatenate((data_prev, train)))

data_prev_scaled = scaler.transform(data_prev)
train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)

# %%
import numpy as np


def create_sequences(data, seq_len=60, data_prev=None):
    X, y = [], []
    if data_prev is not None:
        data = np.concatenate((data_prev[-seq_len:], data))
    for i in range(seq_len, len(data)):
        X.append(data[i - seq_len : i])
        y.append(data[i, 0])
    return np.array(X), np.array(y).reshape(-1, 1)


X_train, y_train = create_sequences(train_scaled, SEQ_LEN, data_prev)
X_test, y_test = create_sequences(test_scaled, SEQ_LEN, train_scaled)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1164, 30, 1) (1164, 1)
# (292, 30, 1) (292, 1)

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import (
    MultiHeadAttention,
    LayerNormalization,
    Input,
    LSTM,
    Dropout,
    GlobalAveragePooling1D,
    Dense,
)


tf.keras.backend.clear_session()


class SelfAttentionBlock(tf.keras.layers.Layer):
    def __init__(self, num_heads=4, key_dim=16, dropout=0.1, **kwargs):
        super().__init__(**kwargs)
        self.mha = MultiHeadAttention(
            num_heads=num_heads, key_dim=key_dim, dropout=dropout
        )
        self.norm = LayerNormalization()

    def call(self, x):
        attn = self.mha(x, x)
        return self.norm(x + attn)


model = Sequential(
    [
        Input(shape=(SEQ_LEN, len(FEATURES))),
        # LSTM(64, return_sequences=True),
        # Dropout(0.2),
        LSTM(64, return_sequences=True),
        Dropout(0.2),
        LSTM(64),
        Dropout(0.2),
        # LSTM(64, return_sequences=True),
        # Dropout(0.2),
        # SelfAttentionBlock(num_heads=4, key_dim=16, dropout=0.1),
        # GlobalAveragePooling1D(),
        # Dense(32, activation="relu"),
        Dense(1),
    ]
)

model.compile(optimizer="adam", loss="mse")
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,985 (195.25 KB)
#  Trainable params: 49,985 (195.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    callbacks=[
        EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True),
        ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5),
    ],
)

print("***** Training Completed *****")
# Out:
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0224 - val_loss: 0.0125 - learning_rate: 0.0010
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033 - val_loss: 0.0039 - learning_rate: 0.0010
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0026 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0025 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0021 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023 - val_loss: 0.0039 - learning_rate: 0.0010
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0021 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0020 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - val_loss: 0.0067 - learning_rate: 0.0010
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018 - val_loss: 0.0022 - learning_rate: 5.0000e-04
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0054 - learning_rate: 5.0000e-04
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0022 - learning_rate: 5.0000e-04
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0026 - learning_rate: 5.0000e-04
# Epoch 15/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0021 - learning_rate: 5.0000e-04
# Epoch 16/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016 - val_loss: 0.0032 - learning_rate: 5.0000e-04
# Epoch 17/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016 - val_loss: 0.0050 - learning_rate: 5.0000e-04
# Epoch 18/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016 - val_loss: 0.0029 - learning_rate: 5.0000e-04
# Epoch 19/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 20/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 21/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0029 - learning_rate: 2.5000e-04
# Epoch 22/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0019 - learning_rate: 2.5000e-04
# Epoch 23/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0020 - learning_rate: 2.5000e-04
# Epoch 24/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0019 - learning_rate: 2.5000e-04
# Epoch 25/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0031 - learning_rate: 2.5000e-04
# Epoch 26/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - val_loss: 0.0019 - learning_rate: 2.5000e-04
# Epoch 27/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0020 - learning_rate: 2.5000e-04
# Epoch 28/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0019 - learning_rate: 1.2500e-04
# Epoch 29/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0018 - learning_rate: 1.2500e-04
# Epoch 30/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0019 - learning_rate: 1.2500e-04
# Epoch 31/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - val_loss: 0.0020 - learning_rate: 1.2500e-04
# Epoch 32/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0019 - learning_rate: 1.2500e-04
# Epoch 33/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0018 - learning_rate: 6.2500e-05
# Epoch 34/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0018 - learning_rate: 6.2500e-05
# Epoch 35/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - val_loss: 0.0017 - learning_rate: 6.2500e-05
# Epoch 36/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0018 - learning_rate: 6.2500e-05
# Epoch 37/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0018 - learning_rate: 6.2500e-05
# Epoch 38/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0018 - learning_rate: 6.2500e-05
# Epoch 39/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0018 - learning_rate: 6.2500e-05
# Epoch 40/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0017 - learning_rate: 3.1250e-05
# Epoch 41/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0018 - learning_rate: 3.1250e-05
# Epoch 42/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0023 - learning_rate: 3.1250e-05
# Epoch 43/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0018 - learning_rate: 3.1250e-05
# Epoch 44/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0017 - learning_rate: 3.1250e-05
# Epoch 45/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0018 - learning_rate: 1.5625e-05
# Epoch 46/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0017 - learning_rate: 1.5625e-05
# Epoch 47/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0018 - learning_rate: 1.5625e-05
# Epoch 48/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0017 - learning_rate: 1.5625e-05
# Epoch 49/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0018 - learning_rate: 1.5625e-05
# Epoch 50/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - val_loss: 0.0017 - learning_rate: 7.8125e-06
# Epoch 51/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013 - val_loss: 0.0018 - learning_rate: 7.8125e-06
# Epoch 52/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0018 - learning_rate: 7.8125e-06
# Epoch 53/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0017 - learning_rate: 7.8125e-06
# Epoch 54/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - val_loss: 0.0018 - learning_rate: 7.8125e-06
# Epoch 55/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 0.0018 - learning_rate: 3.9063e-06
# Epoch 56/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0018 - learning_rate: 3.9063e-06
# Epoch 57/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0017 - learning_rate: 3.9063e-06
# Epoch 58/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0018 - learning_rate: 3.9063e-06
# Epoch 59/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0018 - learning_rate: 3.9063e-06
# Epoch 60/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0018 - learning_rate: 1.9531e-06
# Epoch 61/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0018 - learning_rate: 1.9531e-06
# Epoch 62/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0018 - learning_rate: 1.9531e-06
# Epoch 63/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0017 - learning_rate: 1.9531e-06
# ***** Training Completed *****

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error


y_pred = model.predict(X_test)
dummy_pred = np.zeros((len(y_pred), len(FEATURES)))
dummy_test = np.zeros((len(y_pred), len(FEATURES)))
dummy_pred[:, 0] = y_pred[:, 0]
dummy_test[:, 0] = y_test[:, 0]

y_pred_inv = scaler.inverse_transform(dummy_pred)[:, 0]
y_test_inv = scaler.inverse_transform(dummy_test)[:, 0]

plt.figure(figsize=(10, 5))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Model Loss")
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(y_test_inv, label="Actual")
plt.plot(y_pred_inv, label="Predicted")
plt.title("Predict Close Price")
plt.legend()
plt.text(
    0.05,
    -0.3,
    f"Ticker: {TICKER}\nStart Time: {START_TIME}\nInterval: {INTERVAL}\nFeatures: {','.join(FEATURES)}\nSequence Length: {SEQ_LEN}",
    transform=plt.gca().transAxes,
)
plt.text(
    0.55,
    -0.3,
    f"MAPE: {1 - mean_absolute_percentage_error(y_test_inv, y_pred_inv):.2%}",
    transform=plt.gca().transAxes,
)
plt.savefig(
    f'output/{datetime.now().strftime("%Y%m%d_%H%M%S")}_{TICKER}_pred.png',
    bbox_inches="tight",
)
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
